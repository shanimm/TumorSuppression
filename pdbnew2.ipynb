# %%
import Bio
import pandas as pd
import numpy as np
import biopandas as bp

# %%
from biopandas.pdb import PandasPdb
ppdb = PandasPdb().fetch_pdb('1wch')

# %%
ppdb.df['ATOM'].head()
# Out:
#   record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0        ATOM            1                 N                  HIS
# 1        ATOM            2                CA                  HIS
# 2        ATOM            3                 C                  HIS
# 3        ATOM            4                 O                  HIS
# 4        ATOM            5                CB                  HIS
#
#   chain_id  residue_number insertion  ... x_coord  y_coord  z_coord  \
# 0        A            2170            ...  11.618  -23.166   25.014
# 1        A            2170            ...  12.862  -22.383   25.253
# 2        A            2170            ...  12.821  -21.561   26.541
# 3        A            2170            ...  11.783  -21.424   27.188
# 4        A            2170            ...  13.143  -21.473   24.059
#
#    occupancy  b_factor  blank_4 segment_id element_symbol charge  line_idx
# 0        1.0     52.20                                  N    NaN       386
# ...

# %%
ppdb.df['ATOM'].head()
# Out:
#   record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0        ATOM            1                 N                  HIS
# 1        ATOM            2                CA                  HIS
# 2        ATOM            3                 C                  HIS
# 3        ATOM            4                 O                  HIS
# 4        ATOM            5                CB                  HIS
#
#   chain_id  residue_number insertion  ... x_coord  y_coord  z_coord  \
# 0        A            2170            ...  11.618  -23.166   25.014
# 1        A            2170            ...  12.862  -22.383   25.253
# 2        A            2170            ...  12.821  -21.561   26.541
# 3        A            2170            ...  11.783  -21.424   27.188
# 4        A            2170            ...  13.143  -21.473   24.059
#
#    occupancy  b_factor  blank_4 segment_id element_symbol charge  line_idx
# 0        1.0     52.20                                  N    NaN       386
# ...

# %%
ppdb.df['ATOM'].residue_name.value_counts()
# Out:
# LEU    276
# ARG    220
# ILE    200
# GLN    186
# GLU    167
# VAL    161
# THR    139
# ASP    136
# LYS    135
# TYR    120
# PHE     99
# PRO     98
# SER     96
# ASN     84
# GLY     80
# HIS     80
# MET     76
# TRP     56
# ALA     55
# CYS     42
# Name: residue_name, dtype: int64

# %%
ppdb.df['ATOM'].element_symbol.value_counts()
# Out:
# C    1592
# O     462
# N     435
# S      17
# Name: element_symbol, dtype: int64

# %%
ppdb.df['ATOM'].atom_name.value_counts()
# Out:
# N      308
# CA     308
# C      308
# O      308
# CB     298
# CG     193
# CD      89
# CD1     83
# CG2     69
# CD2     66
# CG1     48
# OE1     40
# CZ      39
# NE2     29
# OD1     28
# CE1     27
# CE      25
# CE2     23
# OG1     21
# NH2     20
# NE      20
# NH1     20
# OE2     19
# OG      18
# OD2     17
# NZ      15
# ND2     11
# SD      10
# OH      10
# ND1      8
# SG       7
# CH2      4
# NE1      4
# CE3      4
# CZ3      4
# CZ2      4
# OXT      1
# Name: atom_name, dtype: int64

# %%
ppdb.df['ATOM'].residue_number.value_counts()
# Out:
# 2294    14
# 2177    14
# 2298    14
# 2323    14
# 2376    14
#         ..
# 2273     4
# 2449     4
# 2261     4
# 2257     4
# 2349     4
# Name: residue_number, Length: 308, dtype: int64

# %%
#ppdb2=PandasPdb.fetch_pdb('pdb2rgd.ent')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-b84ccfd7e24b> in <module>
# ----> 1 ppdb2=PandasPdb.fetch_pdb('pdb2rgd.ent')
#
# TypeError: fetch_pdb() missing 1 required positional argument: 'pdb_code'

# %%
ppdb.df['ATOM'][ppdb.df['ATOM']['atom_name'] == 'CA'][ppdb.df['ATOM']['b_factor']<=20]
# Out:
# C:\Users\shani\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 764         ATOM          765                CA                  ALA
# 769         ATOM          770                CA                  SER
# 874         ATOM          875                CA                  TYR
# 886         ATOM          887                CA                  ILE
# 894         ATOM          895                CA                  ALA
# 905         ATOM          906                CA                  GLN
# 984         ATOM          985                CA                  TRP
# 1086        ATOM         1087                CA                  ILE
# 1094        ATOM         1095                CA                  ALA
# 1099        ATOM         1100                CA                  MET
# ...

# %%
import math
ppdb.df['ATOM'][ppdb.df['ATOM']['atom_name'] == 'CA']['b_factor'<=10].count()

# %%
ppdb.df['ATOM'].distance=pd.Series(np.floor(math.sqrt(np.square(ppdb.df['ATOM'].x_coord)+np.square(ppdb.df['ATOM'].y_coord)+np.square(ppdb.df['ATOM'].z_coord)))).astype(float)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-f9012bf5dd47> in <module>
# ----> 1 ppdb.df['ATOM'].distance=pd.Series(np.floor(math.sqrt(np.square(ppdb.df['ATOM'].x_coord)+np.square(ppdb.df['ATOM'].y_coord)+np.square(ppdb.df['ATOM'].z_coord)))).astype(float)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in wrapper(self)
#     129         if len(self) == 1:
#     130             return converter(self.iloc[0])
# --> 131         raise TypeError("cannot convert the series to " "{0}".format(str(converter)))
#     132
#     133     wrapper.__name__ = "__{name}__".format(name=converter.__name__)
#
# TypeError: cannot convert the series to <class 'float'>

# %%
ppdb.df['ATOM'].head()
# Out:
#   record_name  atom_number blank_1 atom_name alt_loc residue_name blank_2  \
# 0        ATOM            1                 N                  HIS
# 1        ATOM            2                CA                  HIS
# 2        ATOM            3                 C                  HIS
# 3        ATOM            4                 O                  HIS
# 4        ATOM            5                CB                  HIS
#
#   chain_id  residue_number insertion  ... x_coord  y_coord  z_coord  \
# 0        A            2170            ...  11.618  -23.166   25.014
# 1        A            2170            ...  12.862  -22.383   25.253
# 2        A            2170            ...  12.821  -21.561   26.541
# 3        A            2170            ...  11.783  -21.424   27.188
# 4        A            2170            ...  13.143  -21.473   24.059
#
#    occupancy  b_factor  blank_4 segment_id element_symbol charge  line_idx
# 0        1.0     52.20                                  N    NaN       386
# ...
